# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv

# %%
# 1-a, contains after
# Clean Dataset
    
#import the data for python
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
print(data.head())
data.describe()

# %%
Class_0 = data[data['Class']==0]
Class_1 = data[data['Class']==1]
Class_2 = data[data['Class']==2]
Class_3 = data[data['Class']==3]

# %%
Class_0 = Class_0[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_1 = Class_1[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_2 = Class_2[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]

# %%
Class_3['QRS Interval'].corr(Class_3['T Amplitude'])

# %%
df=Class_3.drop(columns=['Heart Rate', 'RR Interval',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram'])

# %%
df.corr(method='pearson')

# %%
import seaborn as sns
plt.figure(dpi=300)

#sns.scatterplot(x="PR Interval", y="P Scalogram", data=Class_2);
sns.lmplot(x="P Scalogram", y="PR Interval", data=Class_2);
plt.ylabel("PR Interval")
plt.xlabel("PED of P wave")
#plt.gca().legend(('a','b','c','d'))

plt.show()
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3

# %%
#fig, axs = plt.subplots(ncols=2)
#sns.regplot(x="P Scalogram", y="PR Interval", data=Class_2, ax=axs[0])
#sns.regplot(x="P Scalogram", y="PR Interval", data=Class_0, ax=axs[1])
#seaborn_grid = sns.lmplot('P Scalogram', 'PR Interval', col='Class', hue='Class', data=data, sharex=False)
#seaborn_grid.fig.set_figwidth(8)
#left, bottom, width, height = seaborn_grid.fig.axes[0]._position.bounds
#left2, bottom2, width2, height2 = seaborn_grid.fig.axes[1]._position.bounds
#left_diff = left2 - left
#seaborn_grid.fig.add_axes((left2 + left_diff, bottom, width, height))
sns.lmplot(x="P Scalogram", y="PR Interval", hue="Class", data=data);
#plt.gca().legend(('Female Control','Male Control','c','d'))

# %%
#2-compare smell ability during infection between recovered patients and long haulers.
# followup da 80 üstü olan ile, 80 altı olanların, during illnesdaki değerlerini, grafikleştir.
 # duringdeki smell ability değerlerine= smell_during vs plot.

# %%
# Clean Dataset
    
#import the data for python
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
print(data.head())
data.describe()

# %%
#PED PR Interval

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3
# Load the diabetes dataset
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
Class_0 = data[data['Class']==0]
Class_1 = data[data['Class']==1]
Class_2 = data[data['Class']==2]
Class_3 = data[data['Class']==3]
Class_0 = Class_0[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_1 = Class_1[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_2 = Class_2[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]

#SMELL
Xbk = np.array(Class_0['P Scalogram']).reshape(-1, 1)  
Ybk = np.array((Class_0['PR Interval']))
Xbs = np.array(Class_2['P Scalogram']).reshape(-1, 1)  
Ybs = np.array((Class_2['PR Interval']))
Xek = np.array(Class_1['P Scalogram']).reshape(-1, 1)  
Yek = np.array((Class_1['PR Interval']))
Xes = np.array(Class_3['P Scalogram']).reshape(-1, 1)  
Yes = np.array((Class_3['PR Interval']))
linear_regressor = LinearRegression()  
linear_regressor.fit(Xbk, Ybk)  # linear regression
Y_predbk = linear_regressor.predict(Xbk)  # predictions
plt.figure(dpi=300)
#plt.scatter(Xbk, Ybk,color='deeppink')
plt.plot(Xbk, Y_predbk, color='deeppink')
linear_regressor.fit(Xbs, Ybs)  # linear regression
Y_predbs = linear_regressor.predict(Xbs)  # predictions
#plt.scatter(Xbs, Ybs,color='black')
plt.plot(Xbs, Y_predbs, color='black')
linear_regressor.fit(Xek, Yek)  # linear regression
Y_predek = linear_regressor.predict(Xek)  # predictions
plt.plot(Xek, Y_predek, color='blue')
linear_regressor.fit(Xes, Yes)  # linear regression
Y_predes = linear_regressor.predict(Xes)  # predictions
plt.plot(Xes, Y_predes, color='red')
plt.ylabel("PR Interval")
plt.xlabel("PED of P wave")
#plt.title("Correlation")
plt.gca().legend(('Female Control Corr: 0.21',r'Female Athlete Corr: $\bf{0.45}$','Male Control Corr: -0.07','Male Athlete Corr: -0.10'),loc='upper left',fontsize='x-small')

plt.show()

# %%
#QTC vs P SCALOGRAM
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3
# Load the diabetes dataset
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
Class_0 = data[data['Class']==0]
Class_1 = data[data['Class']==1]
Class_2 = data[data['Class']==2]
Class_3 = data[data['Class']==3]
Class_0 = Class_0[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_1 = Class_1[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_2 = Class_2[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]

#SMELL
Xbk = np.array(Class_0['P Scalogram']).reshape(-1, 1)  
Ybk = np.array((Class_0['QTc']))
Xbs = np.array(Class_2['P Scalogram']).reshape(-1, 1)  
Ybs = np.array((Class_2['QTc']))
Xek = np.array(Class_1['P Scalogram']).reshape(-1, 1)  
Yek = np.array((Class_1['QTc']))
Xes = np.array(Class_3['P Scalogram']).reshape(-1, 1)  
Yes = np.array((Class_3['QTc']))
linear_regressor = LinearRegression()  
linear_regressor.fit(Xbk, Ybk)  # linear regression
Y_predbk = linear_regressor.predict(Xbk)  # predictions
plt.figure(dpi=300)
#plt.scatter(Xbk, Ybk,color='deeppink')
plt.plot(Xbk, Y_predbk, color='deeppink')
linear_regressor.fit(Xbs, Ybs)  # linear regression
Y_predbs = linear_regressor.predict(Xbs)  # predictions
#plt.scatter(Xbs, Ybs,color='black')
plt.plot(Xbs, Y_predbs, color='black')
linear_regressor.fit(Xek, Yek)  # linear regression
Y_predek = linear_regressor.predict(Xek)  # predictions
plt.plot(Xek, Y_predek, color='blue')
linear_regressor.fit(Xes, Yes)  # linear regression
Y_predes = linear_regressor.predict(Xes)  # predictions
plt.plot(Xes, Y_predes, color='red')
plt.ylabel("QTc")
plt.xlabel("PED of P wave")
#plt.title("Correlation")
plt.gca().legend(('Female Control Corr: 0.08','Female Athlete Corr: -0.04','Male Control Corr: 0.12',r'Male Athlete Corr: $\bf{-0.47}$'),loc='lower left',fontsize='x-small')

plt.show()

# %%
#Class_3['QTc'].corr(Class_3['P Scalogram']) 
df=Class_3.drop(columns=['Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QRS Scalogram','T Scalogram'])
df.corr(method='pearson')

# %%
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
df=Class_3
df_corr = df.corr()
df_corr[['QTc','P Scalogram']].plot(kind='hist')

# %%
#Bar PLOT Denemeleri
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3
# Load the diabetes dataset
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)

import seaborn as sns
f=plt.figure(dpi=300)
#sns.barplot(y='Heart Rate',x='Groups',data=data);
sns.boxplot(y='T Scalogram',x='Groups',data=data);
f.savefig("Figure8C.pdf", bbox_inches='tight')

# %%
#QTC vs T SCALOGRAM
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3
# Load the diabetes dataset
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
Class_0 = data[data['Class']==0]
Class_1 = data[data['Class']==1]
Class_2 = data[data['Class']==2]
Class_3 = data[data['Class']==3]
Class_0 = Class_0[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_1 = Class_1[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_2 = Class_2[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]

#SMELL
Xbk = np.array(Class_0['T Scalogram']).reshape(-1, 1)  
Ybk = np.array((Class_0['QTc']))
Xbs = np.array(Class_2['T Scalogram']).reshape(-1, 1)  
Ybs = np.array((Class_2['QTc']))
Xek = np.array(Class_1['T Scalogram']).reshape(-1, 1)  
Yek = np.array((Class_1['QTc']))
Xes = np.array(Class_3['T Scalogram']).reshape(-1, 1)  
Yes = np.array((Class_3['QTc']))
linear_regressor = LinearRegression()  
linear_regressor.fit(Xbk, Ybk)  # linear regression
Y_predbk = linear_regressor.predict(Xbk)  # predictions
plt.figure(dpi=300)
#plt.scatter(Xbk, Ybk,color='deeppink')
plt.plot(Xbk, Y_predbk, color='deeppink')
linear_regressor.fit(Xbs, Ybs)  # linear regression
Y_predbs = linear_regressor.predict(Xbs)  # predictions
#plt.scatter(Xbs, Ybs,color='black')
plt.plot(Xbs, Y_predbs, color='black')
linear_regressor.fit(Xek, Yek)  # linear regression
Y_predek = linear_regressor.predict(Xek)  # predictions
plt.plot(Xek, Y_predek, color='blue')
linear_regressor.fit(Xes, Yes)  # linear regression
Y_predes = linear_regressor.predict(Xes)  # predictions
plt.plot(Xes, Y_predes, color='red')
plt.ylabel("QTc")
plt.xlabel("PED of P wave")
#plt.title("Correlation")
plt.gca().legend(('Female Control Corr: 0.21',r'Female Athlete Corr: $\bf{0.45}$','Male Control Corr: -0.07','Male Athlete Corr: -0.10'),loc='upper left',fontsize='x-small')

plt.show()

# %%
#QTC vs QRS SCALOGRAM
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3
# Load the diabetes dataset
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
Class_0 = data[data['Class']==0]
Class_1 = data[data['Class']==1]
Class_2 = data[data['Class']==2]
Class_3 = data[data['Class']==3]
Class_0 = Class_0[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_1 = Class_1[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_2 = Class_2[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]

#SMELL
Xbk = np.array(Class_0['QRS Scalogram']).reshape(-1, 1)  
Ybk = np.array((Class_0['QTc']))
Xbs = np.array(Class_2['QRS Scalogram']).reshape(-1, 1)  
Ybs = np.array((Class_2['QTc']))
Xek = np.array(Class_1['QRS Scalogram']).reshape(-1, 1)  
Yek = np.array((Class_1['QTc']))
Xes = np.array(Class_3['QRS Scalogram']).reshape(-1, 1)  
Yes = np.array((Class_3['QTc']))
linear_regressor = LinearRegression()  
linear_regressor.fit(Xbk, Ybk)  # linear regression
Y_predbk = linear_regressor.predict(Xbk)  # predictions
plt.figure(dpi=300)
#plt.scatter(Xbk, Ybk,color='deeppink')
plt.plot(Xbk, Y_predbk, color='deeppink')
linear_regressor.fit(Xbs, Ybs)  # linear regression
Y_predbs = linear_regressor.predict(Xbs)  # predictions
#plt.scatter(Xbs, Ybs,color='black')
plt.plot(Xbs, Y_predbs, color='black')
linear_regressor.fit(Xek, Yek)  # linear regression
Y_predek = linear_regressor.predict(Xek)  # predictions
plt.plot(Xek, Y_predek, color='blue')
linear_regressor.fit(Xes, Yes)  # linear regression
Y_predes = linear_regressor.predict(Xes)  # predictions
plt.plot(Xes, Y_predes, color='red')
plt.ylabel("QTc")
plt.xlabel("PED of P wave")
#plt.title("Correlation")
plt.gca().legend(('Female Control Corr: 0.21',r'Female Athlete Corr: $\bf{0.45}$','Male Control Corr: -0.07','Male Athlete Corr: -0.10'),loc='upper left',fontsize='x-small')

plt.show()

# %%
#####MANİPÜLASYON####

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
#bayan kontrol 0 bayan sporcu 2 erkek kontrol 1 erkek sporcu 3
# Load the diabetes dataset
from pandas import read_excel
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts2.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)
Class_0 = data[data['Class']==0]
Class_1 = data[data['Class']==1]
Class_2 = data[data['Class']==2]
Class_3 = data[data['Class']==3]
Class_0 = Class_0[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_1 = Class_1[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_2 = Class_2[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]
Class_3 = Class_3[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]

my_sheet2 = 'Sayfa1' # change it to your sheet name of excel file
file_name2 = r'C:\Users\asus\Downloads\husatletler.xlsx' # change it to your excel file
data2 = read_excel(file_name2, sheet_name = my_sheet2)

Class_22 = data2[data2['Class']==2]

Class_22 = Class_22[[ 'Heart Rate', 'RR Interval', 'QRS Interval', 'QRS Amplitude',  'T Amplitude','ST Interval', 'QT Interval', 'P Amplitude', 'PR Interval','QTc','P Scalogram','QRS Scalogram','T Scalogram']]




#SMELL
Xbk = np.array(Class_0['P Scalogram']).reshape(-1, 1)  
Ybk = np.array((Class_0['PR Interval']))
Xbs = np.array(Class_2['P Scalogram']).reshape(-1, 1)  
Ybs = np.array((Class_2['PR Interval']))
Xbs2 = np.array(Class_22['P Scalogram']).reshape(-1, 1)  
Ybs2 = np.array((Class_22['PR Interval']))
Xek = np.array(Class_1['P Scalogram']).reshape(-1, 1)  
Yek = np.array((Class_1['PR Interval']))
Xes = np.array(Class_3['P Scalogram']).reshape(-1, 1)  
Yes = np.array((Class_3['PR Interval']))
linear_regressor = LinearRegression()  
linear_regressor.fit(Xbk, Ybk)  # linear regression
Y_predbk = linear_regressor.predict(Xbk)  # predictions
plt.figure(dpi=300)
#plt.scatter(Xbk, Ybk,color='deeppink')
plt.plot(Xbk, Y_predbk, color='deeppink')
linear_regressor.fit(Xbs, Ybs)  # linear regression
Y_predbs = linear_regressor.predict(Xbs)  # predictions
plt.scatter(Xbs2, Ybs2,color='black')
plt.plot(Xbs, Y_predbs, color='black')
linear_regressor.fit(Xek, Yek)  # linear regression
Y_predek = linear_regressor.predict(Xek)  # predictions
plt.plot(Xek, Y_predek, color='blue')
linear_regressor.fit(Xes, Yes)  # linear regression
Y_predes = linear_regressor.predict(Xes)  # predictions
plt.plot(Xes, Y_predes, color='red')
plt.ylabel("PR Interval")
plt.xlabel("PED of P wave")
#plt.title("Correlation")
plt.gca().legend(('Female Control Corr: 0.21',r'Female Athlete Corr: $\bf{0.45}$','Male Control Corr: -0.07','Male Athlete Corr: -0.10'),loc='upper left',fontsize='x-small')

plt.show()

# %%
#####Linear Regresyon####

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)

data = data.query('Class == 0')
len(data)
# Out:
# 54

# %%
X = np.array(data['HeartRate']).reshape(-1, 1)  
Y = np.array(data['QTc']).reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  # linear regression
Y_pred = linear_regressor.predict(X)  # predictions

# %%
plt.figure(dpi=300)
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel("QTc")
plt.xlabel("Heart Rate")
plt.title("Relationship between them")

plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import metrics
import csv
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
my_sheet = 'Sayfa1' # change it to your sheet name of excel file
file_name = r'C:\Users\asus\Downloads\hus_ts.xlsx' # change it to your excel file
data = read_excel(file_name, sheet_name = my_sheet)

data = data.query('Class == 1')
len(data)
X = np.array(data['PScalogram']).reshape(-1, 1)  
Y = np.array(data['QTc']).reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  # linear regression
Y_pred = linear_regressor.predict(X)  # predictions
plt.figure(dpi=300)
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel("QTc")
plt.xlabel("Heart Rate")
plt.title("Relationship between them")

plt.show()
